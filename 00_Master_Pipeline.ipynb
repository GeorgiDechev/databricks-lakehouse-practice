# %%
# dbutils.notebook.run приема два параметъра: 
# 1. Пътят/Името на тетрадката
# 2. Timeout в секунди (ако надвиши това време, хвърля грешка)

print("🚀 Стартиране на Data Pipeline...")

print("1️⃣ Изпълнява се Bronze слой...")
dbutils.notebook.run("01_Bronze_Layer_Ingestion", 120)

print("2️⃣ Изпълнява се Silver слой...")
dbutils.notebook.run("02_Silver_Layer_Cleanse", 120)

print("3️⃣ Изпълнява се Gold слой...")
dbutils.notebook.run("03_Gold_Layer_Aggregation", 120)

print("✅ Пайплайнът завърши успешно!")
